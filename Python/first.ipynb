# %%
nama = "Neal"
alamat = "Taliwang"
umur = "17 Tahun"
tinggi = 167
print("nama saya " ,nama , "tinggi badan saya" ,tinggi ,end="")
print(" dan umur saya " ,umur ,end="")
print(" alamat saya" ,alamat)
# Out:
# nama saya  Neal tinggi badan saya 167 dan umur saya  17 Tahun alamat saya Taliwang

# %%
name = input("Masukan nama anda ")
print("Nama anda",name)
# Out:
# Nama anda d

# %%
nama = input("Masukan nama ")
umur = input("Masukan umur ")
kelas = input("Masukan kelas ")
lagufav = input("Masukan lagu favorit ")

print("Nama saya : " , nama ,",", "umur saya : " , umur,",", "saya berada di kelas" , kelas , "lagu favorit saya : " , lagufav)
# Out:
# Nama saya :  d , umur saya :  d , saya berada di kelas 2 lagu favorit saya :  3

# %%
i = 32
while (i > 1):
    i -= 2
    print(i)
# Out:
# 28
# 26
# 24
# 22
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4
# 2
# 0

# %%
fruits =["Apple","Banana","Orange","Bluebery"]
for list in fruits:
    print(list)
# Out:
# Apple
# Banana
# Orange
# Bluebery

# %%
age = 40

if (age < 13):
    print("Child")
elif(age < 18):
    print("Teenager")
elif(age > 60):
    print("Elderly")
else:
    print("Adult")
# Out:
# Adult
